# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
#Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.
#Ans:

# Matplotlib is a graphical plotting library.It is used  for creating static, animated, and interactive visualizations in Python. 
# Matplotlib is used for data visualization, plotting different kind of graphs.
# 5 plots that can be plotted using the pyplot module of matplotlib is 
# 1.Bar plot
# 2.Scatter plot
# 3.Pie plot
# 4.Histogram
# 5.Line plot

# %%
#Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
#Note: Also add title, xlabel, and ylabel to the plot.

# %%
#A scatter plot is a diagram where each value in the data set is represented by a dot. Here we nedd two arrays of the same length.

# %%
plt.xlabel("This is X axis")
plt.ylabel("This is Y axis")
plt.title("This is a scatter plot")
color = np.random.rand(50)
plt.scatter(x,y,c = color)

# %%
#Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
#Ans:
#This function helps in creating common layouts of subplots and it also includes the enclosing figure object, in a single call.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])
fig , axs = plt.subplots(4)
axs[0].plot(x1,y1)
axs[1].plot(x2,y2)
axs[2].plot(x3,y3)
axs[3].plot(x4,y4)

# %%
#Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
#Ans:Bar plot is a special type of plot used in matplotlib for visualization of the data is the form of rectangular bars.

# %%
plt.xlabel("Company")
plt.ylabel("Profit")
plt.title("Data plot using bar plot")
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xlabel("Profit")
plt.ylabel("Company")
plt.title("Data plot using bar plot")
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
#Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
#Ans: Boxplot is a plot tool which mainly provides a graphical summary of a data set with features such as minimum, first quartile, median, third quartile, and maximum.
#It is used to get the summary of a set like getting the minimum, maximum, median,mode,mean,1st quartile, 3rd quartile,skewness ,kurtosis.
plt.boxplot(box1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9629e26ce0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9629e27220>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9629e26a40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9629e27760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9629e27a00>],
#  'means': []}

# %%
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f9629c9d510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9629c9d930>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f9629c9d270>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9629c9de70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9629c9e110>],
#  'means': []}
